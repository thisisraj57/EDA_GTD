# %% [markdown]
# <a href="https://colab.research.google.com/github/thisisraj57/basasfasc/blob/main/Copy_of_Global_Terrorism_Analysis_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <b> The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.</b>
#
# # <b> Explore and analyze the data to discover key findings pertaining to terrorist activities. </b>

# %%
Hi mahin
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
filepath = '/content/drive/MyDrive/AlmaBetter/EDA CAPSTONE/Global Terrorism Data.csv'
gta_df = pd.read_csv(filepath, encoding = "ISO-8859-1", engine='python')

# %%
gta_df.head(5)
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...        0         0       0      NaN
# 1  197000000002   1970       0     0  ...        1         1       1      NaN
# 2  197001000001   1970       1     0  ...       -9         1       1      NaN
# 3  197001000002   1970       1     0  ...       -9         1       1      NaN
# 4  197001000003   1970       1     0  ...       -9         1       1      NaN
#
# [5 rows x 135 columns]

# %%
gta_df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# Picking columns relevant for the EDA
#
# Reference Material to pick columns [GTA CodeBook](https://www.start.umd.edu/gtd/downloads/Codebook.pdf)

# %%
useful_columns = ['eventid','iyear','country_txt', 'region_txt','city','crit1','crit2','crit3','attacktype1','attacktype1_txt',
                  'success','suicide','weaptype1','weaptype1_txt','targtype1','targtype1_txt', 'gname','claimed','nkill',
                  ]

# %%
gta_df = gta_df.loc[:, useful_columns]

# %%
gta_df.head(5)
# Out:
#         eventid  iyear  ... claimed nkill
# 0  197000000001   1970  ...     NaN   1.0
# 1  197000000002   1970  ...     NaN   0.0
# 2  197001000001   1970  ...     NaN   1.0
# 3  197001000002   1970  ...     NaN   NaN
# 4  197001000003   1970  ...     NaN   NaN
#
# [5 rows x 19 columns]

# %%
gta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   eventid          181691 non-null  int64
#  1   iyear            181691 non-null  int64
#  2   country_txt      181691 non-null  object
#  3   region_txt       181691 non-null  object
#  4   city             181257 non-null  object
#  5   crit1            181691 non-null  int64
#  6   crit2            181691 non-null  int64
#  7   crit3            181691 non-null  int64
#  8   attacktype1      181691 non-null  int64
#  9   attacktype1_txt  181691 non-null  object
#  10  success          181691 non-null  int64
#  11  suicide          181691 non-null  int64
#  12  weaptype1        181691 non-null  int64
#  13  weaptype1_txt    181691 non-null  object
#  14  targtype1        181691 non-null  int64
#  15  targtype1_txt    181691 non-null  object
#  16  gname            181691 non-null  object
#  17  claimed          115571 non-null  float64
#  18  nkill            171378 non-null  float64
# dtypes: float64(2), int64(10), object(7)
# memory usage: 26.3+ MB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
corrdf = gta_df.corr()

# %%
corrdf
# Out:
#               eventid     iyear     crit1  ...  targtype1   claimed     nkill
# eventid      1.000000  0.999996  0.002019  ...   0.079080  0.141600  0.015351
# iyear        0.999996  1.000000  0.001995  ...   0.079082  0.141486  0.015341
# crit1        0.002019  0.001995  1.000000  ...  -0.040026  0.006403  0.010834
# crit2        0.026215  0.026211 -0.008984  ...  -0.101522  0.005675 -0.019506
# crit3       -0.016789 -0.016784 -0.040589  ...   0.251296 -0.047356 -0.056952
# attacktype1  0.074173  0.074153  0.027544  ...   0.014513  0.020243  0.002475
# success     -0.082972 -0.082963 -0.010733  ...  -0.059637 -0.005985  0.053115
# suicide      0.137743  0.137736  0.019039  ...  -0.023440  0.035791  0.136086
# weaptype1   -0.011716 -0.011737  0.029257  ...   0.019846  0.019681  0.004038
# targtype1    0.079080  0.079082 -0.040026  ...   1.000000 -0.028972  0.008499
# claimed      0.141600  0.141486  0.006403  ...  -0.028972  1.000000  0.014038
# nkill        0.015351  0.015341  0.010834  ...   0.008499  0.014038  1.000000
#
# [12 rows x 12 columns]

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corrdf)

# %%
gta_df
# Out:
#              eventid  iyear  ... claimed nkill
# 0       197000000001   1970  ...     NaN   1.0
# 1       197000000002   1970  ...     NaN   0.0
# 2       197001000001   1970  ...     NaN   1.0
# 3       197001000002   1970  ...     NaN   NaN
# 4       197001000003   1970  ...     NaN   NaN
# ...              ...    ...  ...     ...   ...
# 181686  201712310022   2017  ...     1.0   1.0
# 181687  201712310029   2017  ...     0.0   2.0
# 181688  201712310030   2017  ...     0.0   0.0
# 181689  201712310031   2017  ...     0.0   0.0
# 181690  201712310032   2017  ...     0.0   0.0
#
# [181691 rows x 19 columns]

# %% [markdown]
# Notable correlation observed with
# weapon and type of attack
#
# Mild correlation observed with target type1 and crit3 ( criteria: OUTSIDE INTERNATIONAL HUMANITARIAN LAW)

# %%
gta_df.columns
# Out:
# Index(['eventid', 'iyear', 'country_txt', 'region_txt', 'city', 'crit1',
#        'crit2', 'crit3', 'attacktype1', 'attacktype1_txt', 'success',
#        'suicide', 'weaptype1', 'weaptype1_txt', 'targtype1', 'targtype1_txt',
#        'gname', 'claimed', 'nkill'],
#       dtype='object')

# %% [markdown]
# # Analysis by Type of Attack and Fatalities

# %%
atk = gta_df[~gta_df['nkill'].isna()].groupby(['attacktype1_txt']).agg({'nkill':'sum'})
atk.sort_values(['nkill'], ascending = False).drop('Unknown', axis = 0).plot(kind = 'barh')

# %%
atk
# Out:
#                                         nkill
# attacktype1_txt
# Armed Assault                        160297.0
# Assassination                         24920.0
# Bombing/Explosion                    157321.0
# Facility/Infrastructure Attack         3642.0
# Hijacking                              3718.0
# Hostage Taking (Barricade Incident)    4478.0
# Hostage Taking (Kidnapping)           24231.0
# Unarmed Assault                         880.0
# Unknown                               32381.0

# %% [markdown]
# Armed Assault, Bombing/Explosion, Armed Assault are the
# acts of terrorisms with largest number of fatalities

# %% [markdown]
# ## Armed assault

# %%
armass = gta_df[gta_df.attacktype1_txt =='Armed Assault']
armass.groupby(['region_txt']).agg({'nkill':'sum'}).sort_values(['nkill'], ascending = False).plot(kind='bar')

# %% [markdown]
# Weapon Type

# %%
plt.rcParams['figure.figsize'] = (10,5)
armass.groupby(['weaptype1_txt']).agg({'nkill':'sum'}).sort_values(['nkill'], ascending = False).plot(kind = 'bar')

# %%
plt.rcParams['figure.figsize'] = (15, 10)
armas = gta_df[gta_df.attacktype1_txt =='Armed Assault'].copy()
armas.groupby(['targtype1_txt']).agg({'eventid':'count'}).drop('Unknown',axis=0).plot(x='targtype_txt', y='eventid' ,kind = 'pie')

# %%
plt.rcParams['figure.figsize'] = (25, 8)
armas = gta_df[(gta_df.attacktype1_txt =='Armed Assault') & (~gta_df.gname.isna()) ].copy()
gangs = armas.groupby(['gname']).agg({'eventid': 'count'})
gangs.sort_values(['eventid'], ascending= False).head(20).iloc[1:,:].plot(x='gname', y='eventid',kind = 'pie')

# %%
# Out:
#                                nkill
# region_txt
# Australasia & Oceania           78.0
# Central America & Caribbean  23233.0
# Central Asia                   400.0
# East Asia                      612.0
# Eastern Europe                2046.0
# Middle East & North Africa   26201.0
# North America                  837.0
# South America                16814.0
# South Asia                   39132.0
# Southeast Asia                7745.0
# Sub-Saharan Africa           42224.0
# Western Europe                 975.0

# %% [markdown]
# ## Bombing/Explosion

# %%
gta_df[gta_df.attacktype1_txt =='Bombing/Explosion'].groupby(['region_txt']).agg({'nkill':'sum'}).plot(kind='bar')

# %%
bomb = gta_df[gta_df.attacktype1_txt =='Bombing/Explosion'].copy()
bomb
# Out:
#              eventid  iyear  ... claimed nkill
# 3       197001000002   1970  ...     NaN   NaN
# 7       197001020002   1970  ...     0.0   0.0
# 10      197001050001   1970  ...     NaN   0.0
# 15      197001100001   1970  ...     NaN   NaN
# 17      197001120001   1970  ...     0.0   0.0
# ...              ...    ...  ...     ...   ...
# 181681  201712310016   2017  ...     0.0   1.0
# 181685  201712310020   2017  ...     0.0   0.0
# 181687  201712310029   2017  ...     0.0   2.0
# 181689  201712310031   2017  ...     0.0   0.0
# 181690  201712310032   2017  ...     0.0   0.0
#
# [88255 rows x 19 columns]

# %% [markdown]
# Common Targets of Explosion

# %%
bomb.groupby(['targtype1_txt']).agg({'eventid': 'count'}).sort_values('eventid', ascending =False).drop('Unknown', axis = 0).head(10).plot(x = 'targtype1_txt', y='eventid',kind= 'pie')

# %% [markdown]
# Amount of Explosions per region

# %%
bomb.groupby(['region_txt']).agg({'nkill':'sum'}).plot(kind='bar')

# %% [markdown]
# Top 3 explosion/bombing prone region are
# 1)Middle East and North Africa
# 2)South Asia
# 3)Sub-Saharan Africa

# %% [markdown]
# #### Middle East & North Africa

# %%
midea = bomb[bomb['region_txt']=='Middle East & North Africa'].copy()
midea.groupby(['country_txt']).agg({'nkill': 'sum', 'eventid':'count'}).sort_values(['nkill', 'eventid'],ascending = False).head(10).plot(kind='bar')

# %%
plt.rcParams['figure.figsize'] = (15, 10)
midea.groupby([ 'iyear', 'country_txt',]).agg({'nkill': 'sum'}).unstack().plot()

# %%
midea.groupby(['gname']).agg({'nkill':'sum'}).sort_values(['nkill'], ascending = False).drop('Unknown', axis = 0).head(10).plot(x='gname' , y='nkill' ,kind='pie')

# %% [markdown]
# ####South Asia

# %%
southasia = bomb[bomb['region_txt']=='South Asia'].copy()
southasia.groupby(['country_txt']).agg({'nkill': 'sum', 'eventid':'count'}).sort_values(['nkill', 'eventid'],ascending = False).head(10).plot(kind='bar')

# %%
plt.rcParams['figure.figsize'] = (15, 10)
southasia.groupby([ 'iyear', 'country_txt',]).agg({'nkill': 'sum'}).unstack().plot()

# %%
southasia.groupby(['gname']).agg({'nkill':'sum'}).sort_values(['nkill'], ascending = False).drop('Unknown', axis = 0).head(10).plot(x='gname' , y='nkill' ,kind='pie')

# %% [markdown]
# ####Sub-Saharan Africa

# %%
subsah = bomb[bomb['region_txt']=='Sub-Saharan Africa'].copy()
subsah.groupby(['country_txt']).agg({'nkill': 'sum', 'eventid':'count'}).sort_values(['nkill', 'eventid'],ascending = False).head(10).plot(kind='bar')

# %%
plt.rcParams['figure.figsize'] = (15, 10)
subsah.groupby([ 'iyear', 'country_txt',]).agg({'nkill': 'sum'}).unstack().plot()

# %%
subsah.groupby(['gname']).agg({'nkill':'sum'}).sort_values(['nkill'], ascending = False).drop('Unknown', axis = 0).head(10).plot(x='gname' , y='nkill' ,kind='pie')

# %% [markdown]
# ##Assassination

# %%
assas = gta_df[gta_df.attacktype1_txt =='Assassination']
assas.groupby(['region_txt']).agg({'nkill':'sum'}).plot(kind='bar')

# %%
assas.groupby(['targtype1_txt']).agg({'eventid': 'count'}).sort_values('eventid', ascending =False).drop('Unknown', axis = 0).head(10).plot(x = 'targtype1_txt', y='eventid',kind= 'pie')

# %%
assas.groupby(['region_txt']).agg({'nkill':'sum'}).plot(kind='bar')

# %%
assas.groupby(['weaptype1_txt']).agg({'eventid':'count'}).sort_values(['eventid'], ascending = False).plot(kind = 'bar')

# %% [markdown]
# #Analysis by Region through Time

# %% [markdown]
# ##Global

# %%
plt.rcParams['figure.figsize'] = (10, 5)
time = gta_df.groupby(['iyear','region_txt']).agg({'nkill':'sum'})
time.unstack().plot()

# %% [markdown]
# pink line spike near 2000- september 11 attacks
#
# brown spike is the war tensions refers to the battle of gaza bw Hamas and Fatah. 2009 the gaza war ended explaining the dip
#
# 2010 peaks again with Syrian Civil war and Iraqui Civil War

# %% [markdown]
# ## Comparing Countries

# %% [markdown]
# India and Pakistan

# %%
gta_df[(gta_df)]

# %% [markdown]
# Israel and Palenstine
